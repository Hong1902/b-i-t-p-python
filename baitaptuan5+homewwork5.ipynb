# %% [markdown]
# W5A1 Viết hàm truyền vào hai số nguyên a, b. Trả về số lớn hơn trong hai số. def Max_Of_Two( a, b) ->
# int:

# %%
def Max_Of_Two(a,b):
    if a>b:
        return (a)
    elif b>a:
        return(b)
    elif a==b:
        return(a)
assert Max_Of_Two(1,2)==2
assert Max_Of_Two(3,2)==3
assert Max_Of_Two(4,2)==4
assert Max_Of_Two(1,5)==5
assert Max_Of_Two(6,2)==6
assert Max_Of_Two(7,2)==7
print("all tests accepted")
# Out:
# all tests accepted

# %% [markdown]
# W5A2 Viết hàm hoán đổi hai số nguyên. def swap(a, b) -> Tuple[int, int]:

# %%
def swap(a,b) -> (int,int):
    return(b,a)
assert swap(10,20)==(20,10)
assert swap(0,20)==(20,0)
assert swap(1,20)==(20,1)
assert swap(10,2)==(2,10)
assert swap(1,2)==(2,1)
print("all tests accepted")
# Out:
# all tests accepted

# %% [markdown]
# W5A3 Viết hàm kiểm tra một số có phải là số nguyên tố hay không?

# %%
def so_nguyen_to(a:int)->bool:
    if a<2:
        return(False)
    elif a==2:
        return(True)
    else:
        for i in range(2,a//2+1):
            if a%i==0:
                return(False)
            return(True)
assert so_nguyen_to(10)==(False)
assert so_nguyen_to(11)==(True)
assert so_nguyen_to(1)==(False)
assert so_nguyen_to(2)==(True)
assert so_nguyen_to(100)==(False)
print("all test accepted")
# Out:
# all test accepted

# %% [markdown]
# W5A4 VIết hàm kiểm tra một số có phải số hoàn hảo hay không, xử lý trên dữ liệu kiểu số nguyên

# %%
def so_hoan_hao(n):
    tong=0
    for i in range(1,n//2+1):
        if n%i==0:
            tong+=i
    return tong==n
assert so_hoan_hao(28)==True
assert so_hoan_hao(6)==True
assert so_hoan_hao(19)==False
assert so_hoan_hao(2)==False
assert so_hoan_hao(14)==False
assert so_hoan_hao(7)==False
print("all test accepted")
# Out:
# all test accepted

# %% [markdown]
# W5A5 Viết hàm đưa vào một list số nguyên và một số nguyên dương k. Hãy tìm và trả về vị trí của phần tử
# đầu tiên có giá trị k trong list số nguyên, nếu không có thì trả về -1

# %%
def find_index(lst, k):
    for i in range(len(lst)):
        if lst[i] == k:
            return (i+1)
    return -1
my_list=[19,2,7,14]
print(find_index(my_list,19))
# Out:
# 1

# %% [markdown]
# W5A6 Viết hàm tính giai thừa. Nhập vào số nguyên n, trả về giai thừa của n (n!)

# %%
n=int(input())
def giai_thua_cua(n):
    a=1
    for i in range(1,n+1):
        a=a*i
    return a
print(f"Giai thừa của {n} là: {giai_thua_cua(n)}")
# Out:
# Giai thừa của 5 là:120

# %% [markdown]
# W5A7 Viết hàm giả lập một máy tính bỏ túi.
# Hàm thực hiện tính toán kết quả của phép toán giữa số \( num1 \) và \( num2 \) với toán tử \( operat
# \)
# Biết các toán tử đơn giản thực hiện phép toán lần lượt là:
# Phép trừ \( - \)
# Phép cộng \( + \)
# Phép chia \( / \)
# Phép nhân \( * \)
# Kết quả làm tròn đến chữ số thập phân thứ hai.
# Đầu vào: Hai số thực và phép toán cần thực hiện (trong số các phép toán \(+, -, *, /\)).
# Đầu ra: Kết quả phép toán

# %%
a,b=map(int,input().split())
def tong(a,b):
    return(a+b)
def hieu(a,b):
    return(a-b)
def tich(a,b):
    return(a*b)
def thuong(a,b):
    y=a/b
    return(f"{y:.2f}")
print(tong(a,b))
print(hieu(a,b))
print(tich(a,b))
print(thuong(a,b))
# Out:
# 33
# 5
# 266
# 1.36

# %% [markdown]
# W5A8 Khoảng cách Hamming giữa hai số nguyên là số lượng vị trí khác nhau giữa hai dãy bits tương ứng
# của chúng. Ví dụ: Khoảng cách Hamming giữa 1 (1) và 4 (100) là 2.
# Cho hai số nguyên x và y, hãy viết hàm trả về khoảng cách Hamming giữa hai số này.
# Khoảng cách Hamming là cái tên được đặt theo tên của Richard Hamming, người giới thiệu lý
# thuyết này trong tài liệu có tính cơ sở của ông về mã phát hiện lỗi và sửa lỗi (error-detecting and
# error-correcting codes). Nó được sử dụng trong kỹ thuật viễn thông để tính số lượng các bit trong
# một từ nhị phân (binary word) bị đổi ngược, như một hình thức để ước tính số lỗi xảy ra trong quá
# trình truyền thông, và vì thế, đôi khi, nó còn được gọi là khoảng cách tín hiệu (signal distance). Việc
# phân tích trọng số Hamming của các bit còn được sử dụng trong một số ngành, bao gồm lý thuyết
# tin học, lý thuyết mã hóa, và mật mã học. Tuy vậy, khi so sánh các dãy ký tự có chiều dài khác
# nhau, hay các dãy ký tự có xu hướng không chỉ bị thay thế không thôi, mà còn bị ảnh hưởng bởi dữ
# liệu bị lồng thêm vào, hoặc bị xóa đi, phương pháp đo lường phức tạp hơn, như khoảng cách
# Levenshtein (Levenshtein distance) là một phương pháp có tác dụng và thích hợp hơn.

# %%
def ten_to_bin(n:int)->str:
    ans=""
    while n>0:
        du=n%2
        ans=chr(du+ord("0"))+ans
        n//=2
    return ans
def hamMing(n:int,m:int)->int:
    n_bin=ten_to_bin(n)
    m_bin=ten_to_bin(m)
    while(len(n_bin)<len(m_bin)):
        n_bin="0"+n_bin
    while(len(m_bin)<len(n_bin)):
        m_bin="0"+m_bin
    ans=0
    for i in range(len(n_bin)):
        if (m_bin[i]!=n_bin[i]):
            ans+=1
    return ans
assert hamMing(1,4)==2
assert hamMing(123456,32321)==6
assert hamMing(87654321,421321835)==15
assert hamMing(8989,8989)==0
print("all test completed")
# Out:
# all test completed

# %% [markdown]
# W5A9 Viết hàm trả về tổng các chữ số của số nguyên dương n

# %%
n=int(input())
def tong_cac_chu_so(n):
    a=0
    while n>0:
        y=n%10
        a=a+y
        n=n//10
    return(a)
print(tong_cac_chu_so(n))
# Out:
# 6

# %% [markdown]
# W5A10 Hai từ được gọi là đẳng cấu nếu các kí tự trong một từ có thể được ánh xạ để được từ còn lại. Ánh
# xạ một kí tự nghĩa là thay đổi toàn bộ các kí tự đó trong từ bởi một kí tự khác. Thứ tự của các kí tự
# được giữ không đổi. Hai kí tự khác nhau không thể ánh xạ đến cùng một kí tự, nhưng một kí tự có
# thể ánh xạ thành chính nó. Ví dụ, từ "abca" và "zbxz" là hai từ đẳng cấu vì ta có thể ánh xạ 'a' thành
# 'z', 'b' thành 'b' và 'c' thành 'x'.
# Viết hàm trả về \(true\) nếu hai từ \(a\) và \(b\) là đẳng cấu, ngược lại \(false\). Bạn có thể giả sử hai
# từ đầu vào có cùng độ dài.

# %%
def kiem_tra_dang_cau(a, b):
    map_a_to_b = {}
    map_b_to_a = {}
    for char_a, char_b in zip(a, b):
        if char_a in map_a_to_b:
            if map_a_to_b[char_a] != char_b:
                return False
        else:
            map_a_to_b[char_a] = char_b
        if char_b in map_b_to_a:
            if map_b_to_a[char_b] != char_a:
                return False
        else:
            map_b_to_a[char_b] = char_a           
    return True
print("=== CHƯƠNG TRÌNH KIỂM TRA CHUỖI ĐẲNG CẤU ===")
print("Lưu ý: Đề bài yêu cầu hai chuỗi phải có cùng độ dài.\n")
tu_1 = input("Nhập chuỗi thứ nhất (a): ")
tu_2 = input("Nhập chuỗi thứ hai (b): ")
print("-" * 40)
if len(tu_1) != len(tu_2):
    print("[Lỗi]: Hai chuỗi bạn nhập có độ dài khác nhau!")
    print(f"   Chuỗi '{tu_1}' dài {len(tu_1)} ký tự.")
    print(f"   Chuỗi '{tu_2}' dài {len(tu_2)} ký tự.")
    print("Vui lòng chạy lại chương trình và nhập hai chuỗi dài bằng nhau.")
else:
    ket_qua = kiem_tra_dang_cau(tu_1, tu_2)
    if ket_qua == True:
        print(f" Kết quả: True")
        print(f"   Giải thích: Hai chữ '{tu_1}' và '{tu_2}' LÀ chuỗi đẳng cấu.")
    else:
        print(f" Kết quả: False")
        print(f"   Giải thích: Hai chữ '{tu_1}' và '{tu_2}' KHÔNG PHẢI là chuỗi đẳng cấu.")
# Out:
# === CHƯƠNG TRÌNH KIỂM TRA CHUỖI ĐẲNG CẤU ===
# Lưu ý: Đề bài yêu cầu hai chuỗi phải có cùng độ dài.
#
# ----------------------------------------
#  Kết quả: True
#    Giải thích: Hai chữ '12' và '23' LÀ chuỗi đẳng cấu.

# %% [markdown]
# W5A11  Viết hàm is_product_divisible_by_10(a, b) trả về True nếu tích a*b chia hết cho 10, ngược lại False

# %%
a,b=map(int,input().split())
def  is_product_divisible_by_10(a, b):
    y=a*b
    if y%10==0:
        return(True)
    else:
        return(False)
print(is_product_divisible_by_10(a,b))
# Out:
# True

# %% [markdown]
# W5A12 Viết hàm divide_with_remainder(dividend, divisor) trả về bộ (q, r) sao cho dividend = divisor*q + r và
# 0 <= |r| < |divisor|

# %%
dividend = int(input())
divisor = int(input())
def divide_with_remainder(dividend, divisor):
    q = dividend // divisor
    r = dividend % divisor
    return (q, r)

print(divide_with_remainder(dividend, divisor))
# Out:
# (0, 12)

# %% [markdown]
# W5A13 Viết hàm max_of_two(a, b) trả về số lớn hơn trong hai số.

# %%
a,b=map(int,input().split())
def Max_Of_Two(a,b):
    if a>b:
        return (a)
    elif b>a:
        return(b)
    elif a==b:
        return(a)
print(Max_Of_Two(a,b))
# Out:
# 44

# %% [markdown]
# W5A14 Viết hàm compute(a, b, op) thực hiện phép tính a (+|-|*|/) b tùy theo ký tự op

# %%
a,b=map(int,input().split())
op=input()
def compute_hien_dai(a, b, op):
    match op:
        case '+':
            return a + b
        case '-':
            return a - b
        case '*':
            return a * b
        case '/':
            return a / b if b != 0 else "Lỗi chia cho 0"
        case _:
            return "Phép toán không hợp lệ"
print(compute_hien_dai(a,b,op))
# Out:
# 35

# %% [markdown]
# W5A15 Viết hàm is_right_triangle(a, b, c) trả về True nếu ba số có thể là ba cạnh của tam giác vuông.

# %%
a,b,c=map(int,input().split())
def  is_right_triangle(a, b, c):
    if a+b>c and b+c>a and c+a>b :
        if a*a+b*b==c*c or a*a+c*c==b*b or c*c+b*b==a*a:
            return(True)
        else:
            return(False)
    else:
        return("Không là tam giác")
print (is_right_triangle(a,b,c))
# Out:
# False

# %% [markdown]
# W5A16 Viết hàm kiểm tra một số có phải số Amstronhg hay không? Hàm trả về kiểu bool, có tham số là một số
# nguyên x

# %%
x=int(input())
def la_so_Ams(x):
    tong=0
    n=len(str(x))
    so_ban_dau=n
    while n>0:
        y=n%10
        tong=tong+y**n
        n=n//10
    return(tong==so_ban_dau)
print(la_so_Ams(x))
# Out:
# False

# %% [markdown]
# W5A17 Viết hàm kiểm tra một số có phải số chính phương hay không? Hàm trả về kiểu bool, có tham số là một số
# nguyên x

# %%
x=int(input())
def so_chinh_phuong(x):
    if x**0.5-int(x**0.5)==0:
        return(True)
    else:
        return(False)
print(so_chinh_phuong(x))
# Out:
# False

# %% [markdown]
# W5A18  VIết hàm kiểm tra một số có phải số đối xứng không, xử lý trên dữ liệu kiểu số nguyên.

# %%
n=int(input())
def so_doi_xung(n):
    y=0
    so_ban_dau=n
    while n>0:
        y=y*10+n%10
        n=n//10
    return (y==so_ban_dau)
print(so_doi_xung(n))
# Out:
# False

# %% [markdown]
# W5A19 VIết hàm kiểm tra một số có phải số kỳ diệu hay không, xử lý trên dữ liệu kiểu số nguyên

# %%
n=int(input())
def so_ky_dieu(n):
    if n<1:
        return(False)
    while n>9:
        tong_chu_so=0
        while n>0:
            tong_chu_so=tong_chu_so+n%10
            n=n//10
        n=tong_chu_so
    return n==1
print(so_ky_dieu(n))
# Out:
# True

# %% [markdown]
# W5A20 Viết hàm detect_number_type(s) trả về 'int' nếu s là số nguyên, 'float' nếu là số thực, ngược lại 'neither'

# %%
s = input("Nhập vào một giá trị: ")

def detect_number_type(s):
    # Xử lý trường hợp số âm: bỏ dấu trừ ở đầu nếu có
    s_check = s.lstrip('-')
    
    # 1. Kiểm tra số nguyên: Nếu chuỗi chỉ toàn là số
    if s_check.isdigit():
        return 'int'
    
    # 2. Kiểm tra số thực: Nếu xóa 1 dấu chấm đi mà nó là số
    elif '.' in s_check and s_check.replace('.', '', 1).isdigit():
        return 'float'
    
    # 3. Còn lại không phải số
    else:
        return 'neither'

print(detect_number_type(s))
# Out:
# int

# %% [markdown]
# W5A21  Viết hàm is_one_product_of_others(a, b, c) trả về True nếu một trong ba số bằng tích của hai số còn lại

# %%
a,b,c=map(int,input().split())
def one_product_of_others(a, b, c):
    if a==b*c or b==a*c or c==a*b:
        return(True)
    return(False)
print(one_product_of_others(a,b,c))
# Out:
# True

# %% [markdown]
# W5A22 Viết hàm sum_halves(s) nhận chuỗi 6 chữ số và trả về tổng của hai số 3 chữ số đầu và 3 chữ số cuối.

# %%
s=int(input())
def sum_halves(s):
    if 100000<=s<=999999:
        x=s%1000
        y=s//1000
        z=x+y
        return(z)
    else:
        return("Không thỏa mãn")
print(sum_halves(s))
# Out:
# 579

# %% [markdown]
# W5A23  Viết hàm quadratic_roots_count(a, b, c) trả về số nghiệm thực của phương trình a*x^2 + b*x + c = 0

# %%
a,b,c=map(int,input().split())
def quadractic_roots_count(a,b,c):
    y=b*b-4*a*c
    if y<0:
        return("Phương trình vô nghiệm")
    elif y==0:
        return(-b/(2*a))
    else:
        return((-b+y**0.5)/(2*a),(-b-y**0.5)/(2*a))
print(quadractic_roots_count(a,b,c))
# Out:
# -2.0

# %% [markdown]
# W5A24 Viết hàm are_collinear(x1,y1,x2,y2,x3,y3) kiểm tra ba điểm có thẳng hàng hay không.

# %%
def are_collinear(x1, y1, x2, y2, x3, y3):
    if (x1 == x2 and y1 == y2) or (x2 == x3 and y2 == y3) or (x1 == x3 and y1 == y3):
        return "Không phải 3 điểm phân biệt"
    if (x2 - x1) * (y3 - y1) == (y2 - y1) * (x3 - x1):
        return "Thẳng hàng"
    else:
        return "Không thẳng hàng"
assert are_collinear(1, 2, 2, 4, 3, 6) == "Thẳng hàng"
assert are_collinear(1, 2, 2, 3, 3, 4) == "Thẳng hàng" 
print("past")
# Out:
# past

# %% [markdown]
# W5A25 Viết hàm point_in_quadrilateral(quad, p) kiểm tra điểm p có nằm trong hoặc trên biên của tứ giác quad hay
# không. Trong đó: quad là một tứ giác (4 đỉnh – 4 điểm), p là một điểm cần kiểm tra. VD: quad = [(0,0), (4,0), (4,3),
# (0,3)], p = (2,1)

# %%
def point_in_quadrilateral(quad, p):
    px, py = p
    for i in range(4):
        x1, y1 = quad[i]
        x2, y2 = quad[(i + 1) % 4]
        cross_product = (x2 - x1) * (py - y1) - (y2 - y1) * (px - x1)
        if cross_product == 0:
            if min(x1, x2) <= px <= max(x1, x2) and min(y1, y2) <= py <= max(y1, y2):
                return True
    inside = False
    j = 3   
    for i in range(4):
        xi, yi = quad[i]
        xj, yj = quad[j]
        if ((yi > py) != (yj > py)):
  
            intersect_x = (xj - xi) * (py - yi) / (yj - yi) + xi
            
            if px < intersect_x:
                inside = not inside

        
    return inside
quad = [(0,0), (4,0), (4,3), (0,3)]
p1 = (2, 1)
p2 = (4, 1.5)
p3 = (5, 5) 

print(f"Điểm {p1} nằm trong/trên biên tứ giác? -> {point_in_quadrilateral(quad, p1)}")
print(f"Điểm {p2} nằm trong/trên biên tứ giác? -> {point_in_quadrilateral(quad, p2)}")
print(f"Điểm {p3} nằm trong/trên biên tứ giác? -> {point_in_quadrilateral(quad, p3)}")
# Out:
# Điểm (2, 1) nằm trong/trên biên tứ giác? -> True
# Điểm (4, 1.5) nằm trong/trên biên tứ giác? -> True
# Điểm (5, 5) nằm trong/trên biên tứ giác? -> False

# %% [markdown]
# W5A26 Viết hàm trả về a XOR b

# %%
def xor(a, b):
    return a ^ b

# %% [markdown]
# W5A27 Viết hàm trả về số lượng chữ số khác 0 trong n số nguyên nhập vào từ bàn phím (một list)

# %%
def count_nonzero_digits(numbers):
    count = 0
    for num in numbers:
        str_num = str(abs(num))
        for digit in str_num:
            if digit != '0':
                count += 1            
    return count
print("Nhập các số nguyên (cách nhau bởi khoảng trắng):")
numbers_list = list(map(int, input().split()))
total_nonzero = count_nonzero_digits(numbers_list)
print(f"Tổng số lượng chữ số khác 0 là: {total_nonzero}")
# Out:
# Nhập các số nguyên (cách nhau bởi khoảng trắng):
# Tổng số lượng chữ số khác 0 là: 9

# %% [markdown]
# W5A28 Viết hàm tính góc ∠ABC (độ) từ tọa độ A(x1,y1), B(x2,y2), C(x3,y3).

# %%
import math
def calculate_angle_ABC(x1, y1, x2, y2, x3, y3):
    BA_x = x1 - x2
    BA_y = y1 - y2
    BC_x = x3 - x2
    BC_y = y3 - y2
    dot_product = (BA_x * BC_x) + (BA_y * BC_y)
    cross_product = abs((BA_x * BC_y) - (BA_y * BC_x))
    angle_rad = math.atan2(cross_product, dot_product)
    return math.degrees(angle_rad)
print(f"Góc vuông: {calculate_angle_ABC(0, 1, 0, 0, 1, 0)} độ")
print(f"Góc bẹt: {calculate_angle_ABC(1, 1, 2, 2, 3, 3)} độ")
print(f"Góc nhọn: {calculate_angle_ABC(1, 2, 0, 0, 2, 1)} độ")
# Out:
# Góc vuông: 90.0 độ
# Góc bẹt: 180.0 độ
# Góc nhọn: 36.86989764584402 độ

# %% [markdown]
# W5A29 Viết hàm trả về giá trị lớn nhất và nhỏ nhất của ba số a,b,c dưới dạng list [max, min]

# %%
def get_max_min(a, b, c):
    return max(a, b, c), min(a, b, c)
print(*get_max_min(5, -2, 9))
# Out:
# 9 -2

# %% [markdown]
# W5A30 Viết hàm tính hệ số nhị thức C(n, k).

# %%
def binomial_coefficient_manual(n, k):
    if k < 0 or k > n:
        return 0
    if k == 0 or k == n:
        return 1
    if k > n - k:
        k = n - k
    result = 1
    for i in range(1, k + 1):
        result = result * (n - i + 1) / i    
    return result
print(f"C(5, 2) = {binomial_coefficient_manual(5, 2)}")
print(f"C(10, 3) = {binomial_coefficient_manual(10, 3)}")
print(f"C(100, 98) = {binomial_coefficient_manual(100, 98)}")
# Out:
# C(5, 2) = 10.0
# C(10, 3) = 120.0
# C(100, 98) = 4950.0

# %% [markdown]
# W5A31 Viết hàm tính tổng bình phương các số từ 1 đến n

# %%
def tong_binh_phuong(n):
    y=0
    for i in range(1,n+1):
        y=y+i**2
    return y
assert tong_binh_phuong(5)==55
print("pass")
# Out:
# pass

# %% [markdown]
# W5A32 Viết chương trình tính tổng 2 số được nhập theo biểu thức a + b từ bàn phím (Sử dụng hàm eval)

# %%
def tong_hai_so(a,b):
    y=a+b
    return y
assert tong_hai_so(1,2)==3
print("pass")
# Out:
# pass

# %% [markdown]
# W5A33 Viết hàm smart_taxi_fare(car_type, start_hour, km, wait_minutes) tính tổng tiền taxi theo quy tắc giá mở cửa,
# giá km, phí chờ, phụ phí ban đêm và giảm giá.

# %% [markdown]
# W5A34 Viết hàm sum_1_to_n(n) trả về tổng các số x từ 1 đến n, nếu x có các chữ số đôi một khác nhau
# Nếu n ≤ 0 trả về 0

# %%
def sum_1_to_n(n):
    # 1. Kiểm tra điều kiện n <= 0
    if n <= 0:
        return 0
    total_sum = 0
    for x in range(1, n + 1):
        str_x = str(x)
        if len(set(str_x)) == len(str_x):
            total_sum += x
    return total_sum
print(f"Tổng (n = 10): {sum_1_to_n(10)}")
print(f"Tổng (n = 11): {sum_1_to_n(11)}") 
print(f"Tổng (n = -5): {sum_1_to_n(-5)}")
# Out:
# Tổng (n = 10): 55
# Tổng (n = 11): 55
# Tổng (n = -5): 0
